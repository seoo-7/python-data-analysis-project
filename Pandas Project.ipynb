# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt 
import seaborn as sns 
plt.style.use('ggplot')

# %% [markdown]
# # step 1 : Data Understanding

# %%
df = pd.read_csv(r'D:\data analsis with python\data set\coaster_db.csv')

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %% [markdown]
# ## Step 2 : Data Preperation
# 1==> Dropping irrelevant columns and rows
#
#
# 2==>
# Identifying duplicated column
#
#
# 3==>
# Renaming Colum
#
# n4==> s
# Feature Creation

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
columns_to_drop = [ 'Height restriction', 'Model', 'Height',
        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
        'Track layout', 'Fastrack available', 'Soft opening date.1',
        'Closing date',
        'Opened', 
        'Replaced by', 'Website',
        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
        'Single rider line available', 'Restraint Style',
        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
        'speed1', 'speed2', 'speed1_value', 'speed1_unit', 'height_value', 'height_unit']

# %%
df.drop(columns=columns_to_drop , inplace= True)

# %%
df.shape
# Out:
# (1087, 17)

# %%
df.dtypes # we note the column opening_date_clean  is  object
# Out:
# coaster_name           object
# Length                 object
# Speed                  object
# Location               object
# Status                 object
# Opening date           object
# Type                   object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
# i convert object to datatime
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df['opening_date_clean'] # now type is datetime
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'year_introduced', 'latitude', 'longitude',
#        'Type_Main', 'opening_date_clean', 'speed_mph', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
new_columns_names = []

# %%
for n in df.columns:
    new_columns_names.append(n.title())

# %%
new_columns_names
# Out:
# ['Coaster_Name',
#  'Length',
#  'Speed',
#  'Location',
#  'Status',
#  'Opening Date',
#  'Type',
#  'Manufacturer',
#  'Year_Introduced',
#  'Latitude',
#  'Longitude',
#  'Type_Main',
#  'Opening_Date_Clean',
#  'Speed_Mph',
#  'Height_Ft',
#  'Inversions_Clean',
#  'Gforce_Clean']

# %%
New_data = df.copy()

# %%
New_data.columns = new_columns_names

# %%
New_data
# Out:
#                                 Coaster_Name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df = New_data

# %%
df
# Out:
#                                 Coaster_Name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
# another way 
# Rename our columns
'''
df = df.rename(columns={'coaster_name':'Coaster_Name',
                   'year_introduced':'Year_Introduced',
                   'opening_date_clean':'Opening_Date',
                   'speed_mph':'Speed_mph',
                   'height_ft':'Height_ft',
                   'Inversions_clean':'Inversions',
                   'Gforce_clean':'Gforce'})
'''
# Out:
# "\ndf = df.rename(columns={'coaster_name':'Coaster_Name',\n                   'year_introduced':'Year_Introduced',\n                   'opening_date_clean':'Opening_Date',\n                   'speed_mph':'Speed_mph',\n                   'height_ft':'Height_ft',\n                   'Inversions_clean':'Inversions',\n                   'Gforce_clean':'Gforce'})\n"

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Length, Speed, Location, Status, Opening Date, Type, Manufacturer, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date_Clean, Speed_Mph, Height_Ft, Inversions_Clean, Gforce_Clean]
# Index: []

# %%
# is there duplicated in ==> Coaster_Name
df.loc[df.duplicated(subset=['Coaster_Name']) ]
# output ===> 97 rows duplicated
# Out:
#                             Coaster_Name                Length  \
# 43                 Crystal Beach Cyclone      2,953 ft (900 m)
# 60                           Derby Racer                   NaN
# 61           Blue Streak (Conneaut Lake)      2,900 ft (880 m)
# 167        Big Thunder Mountain Railroad                   NaN
# 237    Thunder Run (Canada's Wonderland)      330 m (1,080 ft)
# ...                                  ...                   ...
# 1063                  Lil' Devil Coaster     262.5 ft (80.0 m)
# 1064  Little Dipper (Conneaut Lake Park)                   NaN
# 1080                          Iron Gwazi    4,075 ft (1,242 m)
# 1082             American Dreier Looping    3,444 ft (1,050 m)
# 1084           Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed                   Location              Status  \
# 43           60 mph (97 km/h)         Crystal Beach Park             Removed
# ...

# %%
# if we is want know what's dublicated is Coaster_Name we do
df.query('Coaster_Name == "Crystal Beach Cyclone" ')
# Out:
#              Coaster_Name            Length             Speed  \
# 39  Crystal Beach Cyclone  2,953 ft (900 m)  60 mph (97 km/h)
# 43  Crystal Beach Cyclone  2,953 ft (900 m)  60 mph (97 km/h)
#
#               Location   Status Opening Date  Type        Manufacturer  \
# 39  Crystal Beach Park  Removed         1926  Wood  Traver Engineering
# 43  Crystal Beach Park  Removed         1926  Wood  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date_Clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     Speed_Mph  Height_Ft  Inversions_Clean  Gforce_Clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
df.shape
# Out:
# (1087, 17)

# %%
df.loc[df.duplicated(subset=['Coaster_Name', 'Location','Opening_Date_Clean'])]
# output the all rows duplicated 97rows
# Out:
#                             Coaster_Name                Length  \
# 43                 Crystal Beach Cyclone      2,953 ft (900 m)
# 60                           Derby Racer                   NaN
# 61           Blue Streak (Conneaut Lake)      2,900 ft (880 m)
# 167        Big Thunder Mountain Railroad                   NaN
# 237    Thunder Run (Canada's Wonderland)      330 m (1,080 ft)
# ...                                  ...                   ...
# 1063                  Lil' Devil Coaster     262.5 ft (80.0 m)
# 1064  Little Dipper (Conneaut Lake Park)                   NaN
# 1080                          Iron Gwazi    4,075 ft (1,242 m)
# 1082             American Dreier Looping    3,444 ft (1,050 m)
# 1084           Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed                   Location              Status  \
# 43           60 mph (97 km/h)         Crystal Beach Park             Removed
# ...

# %%
df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','Opening_Date_Clean'])]
# the all rows without duplicated " ~ " ==> it's do that
# Out:
#                                 Coaster_Name                  Length  \
# 0                         Switchback Railway          600 ft (180 m)
# 1                          Flip Flap Railway                     NaN
# 2     Switchback Railway (Euclid Beach Park)                     NaN
# 3               Loop the Loop (Coney Island)                     NaN
# 4               Loop the Loop (Young's Pier)                     NaN
# ...                                      ...                     ...
# 1079            Ice Breaker (roller coaster)        1,900 ft (580 m)
# 1081                   Leviathan (Sea World)  1,000.0 m (3,280.8 ft)
# 1083               Pantheon (roller coaster)      3,328 ft (1,014 m)
# 1085                                 Tumbili          770 ft (230 m)
# 1086          Wonder Woman Flight of Courage      3,300 ft (1,000 m)
#
#                      Speed                        Location  \
# 0         6 mph (9.7 km/h)                    Coney Island
# ...

# %%
# in this cell we droped all rows duplicated 
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','Opening_Date_Clean'])].reset_index(drop = True)

# %%
df
# Out:
#                                Coaster_Name                  Length  \
# 0                        Switchback Railway          600 ft (180 m)
# 1                         Flip Flap Railway                     NaN
# 2    Switchback Railway (Euclid Beach Park)                     NaN
# 3              Loop the Loop (Coney Island)                     NaN
# 4              Loop the Loop (Young's Pier)                     NaN
# ..                                      ...                     ...
# 985            Ice Breaker (roller coaster)        1,900 ft (580 m)
# 986                   Leviathan (Sea World)  1,000.0 m (3,280.8 ft)
# 987               Pantheon (roller coaster)      3,328 ft (1,014 m)
# 988                                 Tumbili          770 ft (230 m)
# 989          Wonder Woman Flight of Courage      3,300 ft (1,000 m)
#
#                     Speed                        Location              Status  \
# ...

# %% [markdown]
# ### Step 3: Feature Understanding

# %%
# (Univariate analysis)
'''
Plotting Feature Distributions :
Histogram
KDE
Boxplot '''
# Out:
# '\nPlotting Feature Distributions :\nHistogram\nKDE\nBoxplot '

# %%
# values counts ==> how many repetition exists in the column
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
df['Year_Introduced'].value_counts().head(10).plot(kind='bar', title = 'Top 10 Roller Coaster Introduced', xlabel = 'Year introduced' , ylabel = 'Counts')
# Out:
# <Axes: title={'center': 'Top 10 Roller Coaster Introduced'}, xlabel='Year introduced', ylabel='Counts'>

# %%
df['Speed_Mph'].plot(kind ='hist', bins = 20 , title = 'Coster speed')
# Out:
# <Axes: title={'center': 'Coster speed'}, ylabel='Frequency'>

# %%
df['Speed_Mph'].plot(kind ='kde', title = 'Coster speed')
# Out:
# <Axes: title={'center': 'Coster speed'}, ylabel='Density'>

# %% [markdown]
# #### # Step 4: Feature Relationships
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %%
df.plot(kind ='scatter', x = 'Speed_Mph' , y = 'Height_Ft' , title = 'Caster Speed vs. Height')
plt.show()

# %%
df.head(1)
# Out:
#          Coaster_Name          Length             Speed      Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)  Coney Island
#
#     Status   Opening Date  Type            Manufacturer  Year_Introduced  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson             1884
#
#    Latitude  Longitude Type_Main Opening_Date_Clean  Speed_Mph  Height_Ft  \
# 0    40.574    -73.978      Wood         1884-06-16        6.0        NaN
#
#    Inversions_Clean  Gforce_Clean
# 0                 0           2.9

# %%
df_visual = sns.scatterplot(x = 'Speed_Mph' , y = 'Height_Ft' , data = df , hue = 'Year_Introduced')
df_visual.set_title("Coster speed vs. height")
plt.show()

# %%
df.head(1)
# Out:
#          Coaster_Name          Length             Speed      Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)  Coney Island
#
#     Status   Opening Date  Type            Manufacturer  Year_Introduced  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson             1884
#
#    Latitude  Longitude Type_Main Opening_Date_Clean  Speed_Mph  Height_Ft  \
# 0    40.574    -73.978      Wood         1884-06-16        6.0        NaN
#
#    Inversions_Clean  Gforce_Clean
# 0                 0           2.9

# %%
sns.pairplot(df,vars=['Year_Introduced','Speed_Mph','Height_Ft'], hue ='Type_Main')
plt.show()

# %%
 df[['Year_Introduced','Speed_Mph','Height_Ft','Inversions_Clean','Gforce_Clean']].dropna().corr()
# Out:
#                   Year_Introduced  Speed_Mph  Height_Ft  Inversions_Clean  \
# Year_Introduced          1.000000   0.171978   0.135413         -0.209887
# Speed_Mph                0.171978   1.000000   0.733999         -0.028705
# Height_Ft                0.135413   0.733999   1.000000         -0.079736
# Inversions_Clean        -0.209887  -0.028705  -0.079736          1.000000
# Gforce_Clean             0.160247   0.607383   0.466482          0.275991
#
#                   Gforce_Clean
# Year_Introduced       0.160247
# Speed_Mph             0.607383
# Height_Ft             0.466482
# Inversions_Clean      0.275991
# Gforce_Clean          1.000000

# %%
df_corr = df[['Year_Introduced','Speed_Mph','Height_Ft','Inversions_Clean','Gforce_Clean']].dropna().corr()

# %%
sns.heatmap(df_corr , annot= True) 
# annot ==> write the data value in each cell
# Out:
# <Axes: >

# %% [markdown]
# # Step 5: Ask a Question about the data
# * Try to answer a question you have about the data using a plot or statistic.
# *
# What are the locations with the fastest roller coasters (minimum of 10)?

# %%
df.head(1)
# Out:
#          Coaster_Name          Length             Speed      Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)  Coney Island
#
#     Status   Opening Date  Type            Manufacturer  Year_Introduced  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson             1884
#
#    Latitude  Longitude Type_Main Opening_Date_Clean  Speed_Mph  Height_Ft  \
# 0    40.574    -73.978      Wood         1884-06-16        6.0        NaN
#
#    Inversions_Clean  Gforce_Clean
# 0                 0           2.9

# %%
df['Speed'].dtype
# Out:
# dtype('O')

# %%
df['Speed'] =pd.to_numeric(df["Speed"],errors='coerce')

# %%
df['Speed'].dtype
# Out:
# dtype('float64')

# %%
pd.set_option('display.max.rows',10)
df
# Out:
#                                Coaster_Name                  Length  Speed  \
# 0                        Switchback Railway          600 ft (180 m)    NaN
# 1                         Flip Flap Railway                     NaN    NaN
# 2    Switchback Railway (Euclid Beach Park)                     NaN    NaN
# 3              Loop the Loop (Coney Island)                     NaN    NaN
# 4              Loop the Loop (Young's Pier)                     NaN    NaN
# ..                                      ...                     ...    ...
# 985            Ice Breaker (roller coaster)        1,900 ft (580 m)    NaN
# 986                   Leviathan (Sea World)  1,000.0 m (3,280.8 ft)    NaN
# 987               Pantheon (roller coaster)      3,328 ft (1,014 m)    NaN
# 988                                 Tumbili          770 ft (230 m)    NaN
# 989          Wonder Woman Flight of Courage      3,300 ft (1,000 m)    NaN
#
# ...

# %%
df_visual = df.filter(items =['Coaster_Name','Location','Speed_Mph']).sort_values(by ='Speed_Mph', ascending = False).head(10)

# %%
df_visual.dropna()
# Out:
#                       Coaster_Name                   Location  Speed_Mph
# 758                  Formula Rossa    Ferrari World Abu Dhabi      149.1
# 648                      Kingda Ka  Six Flags Great Adventure      128.0
# 608            Top Thrill Dragster                Cedar Point      120.0
# 540                     Do-Dodonpa            Fuji-Q Highland      111.8
# 912     Red Force (roller coaster)               Ferrari Land      111.8
# 407  Superman: Escape from Krypton                      Other      100.0
# 409             Tower of Terror II                 Dreamworld      100.0
# 834                     Ring Racer                Nürburgring       99.4
# 525              Steel Dragon 2000         Nagashima Spa Land       95.0
# 867                       Fury 325                  Carowinds       95.0

# %%
df_visual.plot(kind = 'barh',figsize = (12 , 5) )
# Out:
# <Axes: >

# %%
df.loc[df['Speed_Mph'] > 100].sort_values(by= 'Speed_Mph',ascending = False)
# Out:
#                    Coaster_Name              Length  Speed  \
# 758               Formula Rossa  2,000 m (6,562 ft)    NaN
# 648                   Kingda Ka    3,118 ft (950 m)    NaN
# 608         Top Thrill Dragster    2,800 ft (850 m)    NaN
# 540                  Do-Dodonpa  1,244 m (4,081 ft)    NaN
# 912  Red Force (roller coaster)    880 m (2,890 ft)    NaN
#
#                       Location     Status      Opening Date              Type  \
# 758    Ferrari World Abu Dhabi  Operating   4 November 2010  Steel – Launched
# 648  Six Flags Great Adventure  Operating      May 21, 2005  Steel – Launched
# 608                Cedar Point     Closed       May 4, 2003  Steel – Launched
# 540            Fuji-Q Highland     Closed  21 December 2001             Steel
# 912               Ferrari Land  Operating      7 April 2017  Steel – Launched
#
#                   Manufacturer  Year_Introduced  Latitude  Longitude  \
# ...

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_Mph'] \
    .agg(['mean','count',]) \
    .query('count >= 10') \
    .sort_values('mean')
ax
# Out:
#                                  mean  count
# Location
# Alton Towers                42.791667     12
# Carowinds                   43.571429     14
# Kings Island                49.273684     19
# Hersheypark                 50.576923     13
# Kings Dominion              52.083333     12
# Six Flags Great Adventure   53.036364     11
# Canada's Wonderland         53.533333     12
# Six Flags Magic Mountain    57.241176     17
# Cedar Point                 57.833333     18
# Busch Gardens Williamsburg  58.318182     11

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_Mph'] \
    .agg(['mean','count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
